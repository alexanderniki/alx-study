# %% [markdown]
# # Визуализации

# %%
import pandas as pd

# %% [markdown]
# # Matplotlib

# %%
sales = pd.read_csv('../data/sales.csv')
sales.head()
# Out:
#    order_id        date  customer_id         category               region  \
# 0  59570135  2017-10-16          512   Одежда и обувь  Ставропольский край
# 1  16578697  2017-07-18          512   Одежда и обувь  Ставропольский край
# 2  46943601  2017-07-05          512  Бытовая техника  Ставропольский край
# 3  42436035  2017-02-18          512    Спорт и отдых  Ставропольский край
# 4  49798299  2017-09-08          512          Красота  Ставропольский край
#
#    sales  quantity  discount
# 0   1301         2      0.00
# 1   3530         4      0.05
# 2   5773         1      0.10
# 3   4723         3      0.03
# 4   1936         3      0.00

# %% [markdown]
# ### Столбчатая диаграмма

# %%
sales['category'].hist()
# Out:
# <Axes: >

# %% [markdown]
# Вариант получше

# %%
import matplotlib.pyplot as plt

# %%
sales['category'].nunique()
# Out:
# 8

# %%
plt.figure(figsize=(12, 4))

values, bins, bars = plt.hist(sales['category'], bins=15, label='Nebraska')

plt.ylabel('Количество заказов')
plt.legend()

# %% [markdown]
# Еще более продвинутый вариант

# %%
sales.groupby(['region', 'category']).size().unstack()
# Out:
# category               Аптека  Бытовая техника  Дача и сад  Красота  Мебель  \
# region
# Амурская область        30616            17793       26484     8829    4138
# Владимирская область    12490             7428       10666     3643    1721
# Иркутская область       18264            10783       15701     5429    2481
# Краснодарский край      18277            10814       15957     5459    2523
# Красноярский край       12487             7290       10707     3623    1746
# Ленинградская область   24164            14162       21161     7283    3148
# Московская область      30549            17774       26363     9038    3975
# Приморский край         18719            10971       15969     5393    2462
# Смоленская область      12221             7085       10615     3640    1653
# Ставропольский край     15346             8780       13171     4375    2085
# Хабаровский край        24420            14374       20938     7263    3309
#
# category               Одежда и обувь  Продукты питания  Спорт и отдых
# region
# Амурская область                41029             53952          36001
# Владимирская область            16800             21851          14652
# Иркутская область               24695             31969          21338
# Краснодарский край              24713             32346          21518
# Красноярский край               16665             21916          14520
# Ленинградская область           32440             42844          28731
# Московская область              40560             53573          35664
# Приморский край                 24576             32507          21893
# Смоленская область              16322             21305          14314
# Ставропольский край             20538             26937          17951
# Хабаровский край                32623             43093          28601

# %%
sales.groupby(['region', 'category']).size().unstack().plot(kind='bar', stacked=True)
# Out:
# <Axes: xlabel='region'>

# %% [markdown]
# ### Линейная диаграмма

# %% [markdown]
# Выделим год и месяц из даты заказа

# %%
sales['month'] = sales['date'].str.slice(start=0, stop=7)
sales.head()
# Out:
#    order_id        date  customer_id         category               region  \
# 0  59570135  2017-10-16          512   Одежда и обувь  Ставропольский край
# 1  16578697  2017-07-18          512   Одежда и обувь  Ставропольский край
# 2  46943601  2017-07-05          512  Бытовая техника  Ставропольский край
# 3  42436035  2017-02-18          512    Спорт и отдых  Ставропольский край
# 4  49798299  2017-09-08          512          Красота  Ставропольский край
#
#    sales  quantity  discount    month
# 0   1301         2      0.00  2017-10
# 1   3530         4      0.05  2017-07
# 2   5773         1      0.10  2017-07
# 3   4723         3      0.03  2017-02
# 4   1936         3      0.00  2017-09

# %%
sales_by_month = sales.groupby(['month', 'category', 'region']).agg({'sales': 'sum'}).reset_index()
sales_by_month.head()
# Out:
#      month category                region    sales
# 0  2017-01   Аптека      Амурская область  1255914
# 1  2017-01   Аптека  Владимирская область   483450
# 2  2017-01   Аптека     Иркутская область   754794
# 3  2017-01   Аптека    Краснодарский край   702687
# 4  2017-01   Аптека     Красноярский край   451583

# %%
sales_graph = sales_by_month.groupby(['month']).agg({'sales': 'sum'}).reset_index()
sales_graph
# Out:
#       month      sales
# 0   2017-01  100584502
# 1   2017-02  127351202
# 2   2017-03  183609747
# 3   2017-04  218601894
# 4   2017-05  250450533
# 5   2017-06  253960232
# 6   2017-07  247865266
# 7   2017-08  219494168
# 8   2017-09  176336823
# 9   2017-10  145767793
# 10  2017-11  120348725
# 11  2017-12  119720835
# 12  2018-01  136429443
# 13  2018-02  146080057
# 14  2018-03  198775363
# 15  2018-04  227563556
# 16  2018-05  256821986
# 17  2018-06  256411912
# 18  2018-07  249626075
# 19  2018-08  217295233
# 20  2018-09  179538556
# 21  2018-10  148251188
# 22  2018-11  121193566
# 23  2018-12  120969874
# 24  2019-01  135681929
# 25  2019-02  143706456
# 26  2019-03  196387722
# 27  2019-04  223684625
# 28  2019-05  258275253
# 29  2019-06  253520654
# 30  2019-07  247993490
# 31  2019-08  214150200
# 32  2019-09  166658818
# 33  2019-10  129487369

# %%
plt.figure(figsize=(15, 4))

plt.plot(sales_graph['month'], sales_graph['sales'])
plt.xticks(plt.xticks()[0][1::2])
# Out:
# ([<matplotlib.axis.XTick at 0x118669f90>,
#   <matplotlib.axis.XTick at 0x11cde0550>,
#   <matplotlib.axis.XTick at 0x11cde0cd0>,
#   <matplotlib.axis.XTick at 0x11cde1450>,
#   <matplotlib.axis.XTick at 0x11cde1bd0>,
#   <matplotlib.axis.XTick at 0x11cde2350>,
#   <matplotlib.axis.XTick at 0x11cde2ad0>,
#   <matplotlib.axis.XTick at 0x11cde3250>,
#   <matplotlib.axis.XTick at 0x11cde39d0>,
#   <matplotlib.axis.XTick at 0x11ce08190>,
#   <matplotlib.axis.XTick at 0x11ce08910>,
#   <matplotlib.axis.XTick at 0x11ce09090>,
#   <matplotlib.axis.XTick at 0x11ce09810>,
#   <matplotlib.axis.XTick at 0x11ce09f90>,
#   <matplotlib.axis.XTick at 0x11ce0a710>,
#   <matplotlib.axis.XTick at 0x11ce0ae90>,
#   <matplotlib.axis.XTick at 0x11ce0b610>],
#  [Text(1, 0, '2017-02'),
#   Text(3, 0, '2017-04'),
#   Text(5, 0, '2017-06'),
#   Text(7, 0, '2017-08'),
#   Text(9, 0, '2017-10'),
#   Text(11, 0, '2017-12'),
#   Text(13, 0, '2018-02'),
#   Text(15, 0, '2018-04'),
#   Text(17, 0, '2018-06'),
#   Text(19, 0, '2018-08'),
#   Text(21, 0, '2018-10'),
#   Text(23, 0, '2018-12'),
#   Text(25, 0, '2019-02'),
#   Text(27, 0, '2019-04'),
#   Text(29, 0, '2019-06'),
#   Text(31, 0, '2019-08'),
#   Text(33, 0, '2019-10')])

# %% [markdown]
# # Seaborn

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# Набор стилей для графиков

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'petroff10',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
plt.style.use('ggplot')

# %%
plt.figure(figsize=(12, 3))
sns.lineplot(x='month', y='sales', data=sales_by_month)
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %% [markdown]
# Добавляем детализацию по категории

# %%
plt.figure(figsize=(12, 3))
sns.lineplot(x='month', y='sales', data=sales_by_month, hue='category')
# Out:
# <Axes: xlabel='month', ylabel='sales'>

# %% [markdown]
# Пример из документации

# %%
# так можно импортировать датасеты
df = sns.load_dataset('tips')
df.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
sns.pairplot(df, hue ='sex')
plt.show()

# %% [markdown]
# Тепловая карта

# %%
glue = sns.load_dataset("glue").pivot(columns="Task", index="Model", values="Score")
glue.head()
# Out:
# Task         CoLA  MNLI  MRPC  QNLI   QQP   RTE  SST-2  STS-B
# Model
# BERT         60.5  86.7  89.3  92.7  72.1  70.1   94.9   87.6
# BiLSTM       11.6  65.6  81.8  74.6  62.5  57.4   82.8   70.3
# BiLSTM+Attn  18.6  67.6  83.9  74.3  60.1  58.4   83.0   72.8
# BiLSTM+CoVe  18.5  65.4  78.7  70.8  60.6  52.7   81.9   64.4
# BiLSTM+ELMo  32.1  67.2  84.7  75.5  61.1  57.4   89.3   70.3

# %%
sns.heatmap(glue, annot=True)
# Out:
# <Axes: xlabel='Task', ylabel='Model'>

# %% [markdown]
# # Plotly

# %%
import plotly.express as px

# %%
fig = px.line(sales_graph, x='month', y='sales', title='Продажи по месяцам')
fig.show()

# %%
# добавить элемент управления - например, период

fig = px.line(sales_graph, x='month', y='sales')
fig.update_layout(xaxis=dict(rangeslider=dict(visible=True)))
fig.show()

# %% [markdown]
# ### Добавим выбор категории

# %%
sales_by_month.head()
# Out:
#      month category                region    sales
# 0  2017-01   Аптека      Амурская область  1255914
# 1  2017-01   Аптека  Владимирская область   483450
# 2  2017-01   Аптека     Иркутская область   754794
# 3  2017-01   Аптека    Краснодарский край   702687
# 4  2017-01   Аптека     Красноярский край   451583

# %%
sales_category = sales_by_month.groupby(['month', 'category'], as_index=False).sum()
sales_category.head()
# Out:
#      month         category  \
# 0  2017-01           Аптека
# 1  2017-01  Бытовая техника
# 2  2017-01       Дача и сад
# 3  2017-01          Красота
# 4  2017-01           Мебель
#
#                                               region     sales
# 0  Амурская областьВладимирская областьИркутская ...   8782967
# 1  Амурская областьВладимирская областьИркутская ...   9694190
# 2  Амурская областьВладимирская областьИркутская ...  39043515
# 3  Амурская областьВладимирская областьИркутская ...    672324
# 4  Амурская областьИркутская областьКраснодарский...    399374

# %%
fig = px.line(sales_category, x='month', y='sales', color='category')

fig.update_layout(
    updatemenus=[
        {
            "buttons": [{ "label": 'Все категории', "method": "restyle", "args": [{"visible": [True for _ in fig.data]}], }] +
            [
                {
                    "label": t.name,
                    "method": "restyle",
                    "args": [{"visible": [t2.name == t.name for t2 in fig.data]}],
                }
                for t in fig.data
            ]
        }
    ]
)

fig.show()
